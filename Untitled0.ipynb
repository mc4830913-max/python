# %% [markdown]
# <a href="https://colab.research.google.com/github/mc4830913-max/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# typecasting

# %%
print(type(int(4.16)))
print(float(19))
print(bool(1))
print(int('14'))
print(float(True))
print(int(False))
# Out:
# <class 'int'>
# 19.0
# True
# 14
# 1.0
# 0

# %%
print(str(123))
print(str(23.5))
print(str(True))
print(bool(0 ))
print(bool(0.1))
print(bool(4735))
print(bool())
# Out:
# 123
# 23.5
# True
# False
# True
# True
# False

# %%
print(float(int(float('18.44'))))
print(float(int('14')))
print(bool(int(float('1.34567'))))
print(bool(int(float('0.34567'))))
print(str(int(4356.8)))
print(str(float(27)))
# Out:
# 18.0
# 14.0
# True
# False
# 4356
# 27.0
