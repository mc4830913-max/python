# %% [markdown]
# <a href="https://colab.research.google.com/github/mc4830913-max/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
num=6
for i in range(1,num):
  print("*"*i)
for j in range(num,0,-1):
  print("*"*j)
# Out:
# hello
# *
# **
# ***
# ****
# *****
# ******
# *****
# ****
# ***
# **
# *

# %%
print(type("hello"))
print(type(-20))
print(type[1,2,3])
print(type(True))
print('a' ,end=' ')
print('b' ,end=' ')
print('c')
print('29','08','2003',sep="/")
# Out:
# <class 'str'>
# <class 'int'>
# type[1, 2, 3]
# <class 'bool'>
# a b c
# 29/08/2003

# %%
print(34+5)
print(35-45)
print(3/5)
print(35//4)
print(23*56.6)
print(10**10)
print(100%35)
print(True+True+True+False)
print("Monika"+" chauhan")
# Out:
# 39
# -10
# 0.6
# 8
# 1301.8
# 10000000000
# 30
# 3
# Monika chauhan

# %%
# abs
print(abs(-1876))
print(abs(-18.76))

#round
print(round(19.569764325,6))

#power
print(pow(4,6))
print(pow(6,4))
# Out:
# 1876
# 18.76
# 19.569764
# 4096
# 1296

# %%
print(2<6)
print(2>6)
print(2<=6)
print(2>=6)
print(2==6)
print(9<<6)
print(7>>6)
print(2!=6)
print(True==1)
print(False!=0)
print("Monika"==1)
# Out:
# True
# False
# False

# %%
print(True and True)
print(False & True)
print(True and False)
print(False and False)
print(True or True)
print(False or True)
print(True or False)
print(False or False)
print(not True)
print(not False)
print(9&4)
# Out:
# True
# False
# False
# False
# True
# True
# True
# False
# False
# True
# 0
