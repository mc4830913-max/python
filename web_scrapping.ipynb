# %%
import requests 
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup

# %%
link="https://quotes.toscrape.com/"

# %%
res=requests.get(link)

# %%
# print(res.text)

# %%
html=res.text

# %%
# df=open("quotes.html","w")
# df.write(html)
# df.close()

# %%
soup=BeautifulSoup(res.text,"html.parser")

# %%
print(soup.find("span"))
# Out:
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>

# %%
data=[]
for sp in soup.find_all("div",class_="quote"):
    quote         =sp.find("span",class_="text").text[1:-1]
    author        =sp.find("small").text[1:-1]
    author_id     =sp.find("a").get("href")
    tags=[]
    for tag in sp.find_all("a", class_="tag"):
        tags.append(tag.text)
    tags          =",".join(tags)
    data.append([quote,author,author_id,tags])

# %%
df=pd.DataFrame(data,columns=["quote","author","author_id","tags"])
df
# Out:
#                                                quote           author  \
# 0  The world as we have created it is a process o...    lbert Einstei
# 1  It is our choices, Harry, that show what we tr...       .K. Rowlin
# 2  There are only two ways to live your life. One...    lbert Einstei
# 3  The person, be it gentleman or lady, who has n...        ane Auste
# 4  Imperfection is beauty, madness is genius and ...     arilyn Monro
# 5  Try not to become a man of success. Rather bec...    lbert Einstei
# 6  It is better to be hated for what you are than...         ndré Gid
# 7  I have not failed. I've just found 10,000 ways...   homas A. Ediso
# 8  A woman is like a tea bag; you never know how ...  leanor Roosevel
# 9   A day without sunshine is like, you know, night.       teve Marti
#
#                    author_id                                      tags
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %%
for i in range(len(df1["author_id"])):

# %%
# df.to_csv("quotes.csv",index=False)

# %%
data1 =[]
for page in range(1,11):
    link="https://quotes.toscrape.com/page/"+str(page)
    res=requests.get(link)
    soup=BeautifulSoup(res.text,"html.parser")

    for sp in soup.find_all("div",class_="quote"):
        quote         =sp.find("span",class_="text").text[1:-1]
        author        =sp.find("small").text[1:-1]
        author_id     =sp.find("a").get("href")
        tags=[]
        for tag in sp.find_all("a", class_="tag"):
            tags.append(tag.text)
        tags          =",".join(tags)
        data1.append([quote,author,author_id,tags])

# %%
df1=pd.DataFrame(data1,columns=["quote","author","author_id","tags"])
# df1.to_csv("new_quotes.csv",index=False)

# %%
df1["author_link"]="https://quotes.toscrape.com/"+df1["author_id"]
df1.sample(6)
# Out:
#                                                 quote           author  \
# 37     Any fool can know. The point is to understand.    lbert Einstei
# 71  Some people never go crazy. What truly horribl...   harles Bukowsk
# 51            Do one thing every day that scares you.  leanor Roosevel
# 29  One good thing about music, when it hits you, ...         ob Marle
# 86  We are not necessarily doubting that God will ...         .S. Lewi
# 5   Try not to become a man of success. Rather bec...    lbert Einstei
#
#                     author_id                                     tags  \
# 37    /author/Albert-Einstein  knowledge,learning,understanding,wisdom
# 71   /author/Charles-Bukowski                                    humor
# 51  /author/Eleanor-Roosevelt              attributed,fear,inspiration
# 29         /author/Bob-Marley                                    music
# 86          /author/C-S-Lewis                                      god
# ...

# %%
for i in range (len(df1["author_id"])):
    print(("https"+df1["author_id"])[i])
# Out:
# https/author/Albert-Einstein
# https/author/J-K-Rowling
# https/author/Albert-Einstein
# https/author/Jane-Austen
# https/author/Marilyn-Monroe
# https/author/Albert-Einstein
# https/author/Andre-Gide
# https/author/Thomas-A-Edison
# https/author/Eleanor-Roosevelt
# https/author/Steve-Martin
# https/author/Marilyn-Monroe
# https/author/J-K-Rowling
# https/author/Albert-Einstein
# https/author/Bob-Marley
# https/author/Dr-Seuss
# https/author/Douglas-Adams
# https/author/Elie-Wiesel
# https/author/Friedrich-Nietzsche
# https/author/Mark-Twain
# https/author/Allen-Saunders
# https/author/Pablo-Neruda
# https/author/Ralph-Waldo-Emerson
# https/author/Mother-Teresa
# https/author/Garrison-Keillor
# https/author/Jim-Henson
# https/author/Dr-Seuss
# https/author/Albert-Einstein
# https/author/J-K-Rowling
# https/author/Albert-Einstein
# https/author/Bob-Marley
# https/author/Dr-Seuss
# https/author/J-K-Rowling
# https/author/Bob-Marley
# https/author/Mother-Teresa
# ...

# %%
tags=[]
for tag in sp.find_all("a", class_="tag"):
    tags.append(tag.text)
tags    
",".join(tags)
# Out:
# 'humor,obvious,simile'

# %%
print(soup.find("span",class_="text").text[1:-1])
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.

# %%
quotes=[]
for quote in soup.find_all("span",class_="text"):
    quotes.append(quote.text[1:-1])

# %%
for author in soup.find_all("small"):
    print(author.text[1:-1])
# Out:
# lbert Einstei
# .K. Rowlin
# lbert Einstei
# ane Auste
# arilyn Monro
# lbert Einstei
# ndré Gid
# homas A. Ediso
# leanor Roosevel
# teve Marti

# %%
# Out:
#                                                     0                 1  \
# 0   The world as we have created it is a process o...     lbert Einstei
# 1   It is our choices, Harry, that show what we tr...        .K. Rowlin
# 2   There are only two ways to live your life. One...     lbert Einstei
# 3   The person, be it gentleman or lady, who has n...         ane Auste
# 4   Imperfection is beauty, madness is genius and ...      arilyn Monro
# ..                                                ...               ...
# 95  You never really understand a person until you...          arper Le
# 96  You have to write the book that wants to be wr...   adeleine L'Engl
# 97  Never tell the truth to people who are not wor...          ark Twai
# 98          A person's a person, no matter how small.           r. Seus
# 99  ... a mind needs books as a sword needs a whet...  eorge R.R. Marti
#
#                             2  \
# 0     /author/Albert-Einstein
# 1         /author/J-K-Rowling
# ...
