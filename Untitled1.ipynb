# %% [markdown]
# <a href="https://colab.research.google.com/github/mc4830913-max/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#list
# First=[0,1,2,3]
# pd.Series(First)
arr=np.array([0,1,2,3])
pd.Series(arr)
pd.Series(index=[1,2,3,4],data=["tiger","elephent","lion","dog"])

#dictionary
days={'day1':'monday','day2':'tuesday','day3':'wednesday','day4':'thrusday','day5':'friday','day6':'saturday','day7':'sunday'}
pd.Series(days)

#repeat function
s=pd.Series("monika chauhan").repeat(5).reset_index(drop=True)
d=pd.Series(["monika chauhan", "Ganesh"]).repeat([5,6]).reset_index(drop=True)
s[4]
d[9]
d[3:-2]

#aggrigation function
second=["mona",'rimpy','rajni','sanjana','anushka','muskan']
pd.Series(second)
string=pd.Series([23,34,56,65,67,12,43,12,13,37])
#string.agg([min,max,sum,np.mean,np.median])

#series absolute function
string=pd.Series([23,34,56,-65,67,-12,43,12,-13,37])
string.abs()

#append series
string=pd.Series([23,34,56,65,67,12,43,12,13,37])
string1=pd.Series([23,34,56,65,67,12,43,12,13,37])
new=string.append(string1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3135242933.py in <cell line: 0>()
#      32 string=pd.Series([23,34,56,65,67,12,43,12,13,37])
#      33 string1=pd.Series([23,34,56,65,67,12,43,12,13,37])
# ---> 34 new=string.append(string1)
#      35 new
#      36
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
sr1 = pd.Series([1,-2,3])
sr2 = pd.Series([1,2,3])
sr3 = sr2.append(sr1) #not working
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3512006308.py in <cell line: 0>()
#       1 sr1 = pd.Series([1,-2,3])
#       2 sr2 = pd.Series([1,2,3])
# ----> 3 sr3 = sr2.append(sr1)
#       4
#       5 sr3
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'append'
