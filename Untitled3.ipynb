# %% [markdown]
# <a href="https://colab.research.google.com/github/mc4830913-max/python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def logical(a,b):
  print(a and b)
  print(a or b)
  print(not b)
logical(20,8)
# Out:
# 8
# 20
# False

# %%
#condtional if else
n=int(input("enter the number"))
if(n>0):
  print(n,"number is postive")
elif(n==0):
  print(n,"n is neither positve nor negative")
else:
  print(n,"n is negative")


#
m=int(input("enter the number"))
if(m%2==0):
  print(m,": is even number")
else:
  print(m,":is odd number")
# Out:
# enter the number-76
# -76 n is negative
# enter the number19
# 19 m is odd number

# %%
n=int(input("enter the number"))
if(n>0):
  print(n,"number is postive")
if(n<0):
  print(n,"n is  negative")
if(n==0):
  print(n,"n is zero")


for i in range(7,77,7):
    print(i)


n=20
if(n%5==0):
  if(n%3==0):
    print(n,":it is divisible by 5 and 3")
  else:
    print(n,"it is divisble by 5 not 3")
else:
  print(n,":it is not divisble by 5")
# Out:
# enter the number7
# 7 number is postive
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 20 it is divisble by 5 not 3

# %%
n=int(input("enter the number"))
if((n%5==0)and(n%3==0)):
  print(n,"n divisble by both")
else:
  print(n,"n is not divisble by any one of them")


m=int(input("enter the number"))
if((m%5==0)or(m%3==0)):
  print(m,"n divisble by any one of them")
else:
  print(m,"n is not divisble by both")
# Out:
# enter the number38
# 38 n is not divisble by any one of them
# enter the number38
# 38 n is not divisble by both

# %%
n=int(input("enter the number"))
if((n%5==0)and(n%3==0)):
  print(n,"n divisble by both")
elif((n%5==0)or(n%3==0)):
  print(n,"n is divisble by one of them")
else:
  print(n,"n is not divisble by both")
# Out:
# enter the number23
# 23 n is not divisble by both
